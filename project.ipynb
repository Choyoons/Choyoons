# %% [markdown]
# <a href="https://colab.research.google.com/github/Choyoons/Choyoons/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_vgm2 = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/datasets/vgames2.csv')
df_vgm2
# Out:
#        Unnamed: 0                                            Name Platform  \
# 0               1                    Candace Kane's Candy Factory       DS
# 1               2                                  The Munchables      Wii
# 2               3  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP
# 3               4                Deal or No Deal: Special Edition       DS
# 4               5       Ben 10 Ultimate Alien: Cosmic Destruction      PS3
# ...           ...                                             ...      ...
# 16593       16594                         Ice Age 2: The Meltdown       GC
# 16594       16595                     Rainbow Islands: Revolution      PSP
# 16595       16596                                        NBA 2K16      PS3
# 16596       16597                     Toukiden: The Age of Demons      PSV
# 16597       16598                        The King of Fighters '95       PS
#
# ...

# %%
print(df_vgm2.shape)
df_vgm2.info()
df_vgm2.duplicated().sum()
df_vgm2.columns
# Out:
# (16598, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   16598 non-null  int64
#  1   Name         16598 non-null  object
#  2   Platform     16598 non-null  object
#  3   Year         16327 non-null  float64
#  4   Genre        16548 non-null  object
#  5   Publisher    16540 non-null  object
#  6   NA_Sales     16598 non-null  object
#  7   EU_Sales     16598 non-null  object
#  8   JP_Sales     16598 non-null  object
#  9   Other_Sales  16598 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.3+ MB
# Index(['Unnamed: 0', 'Name', 'Platform', 'Year', 'Genre', 'Publisher',
#        'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'],
#       dtype='object')

# %%
df_vgm2.sample(20)
# Out:
#        Unnamed: 0                                               Name Platform  \
# 3998         3999                     Naruto: Gekito Ninja Taisen! 3       GC
# 15042       15043                                 Beyond Good & Evil      PS2
# 9686         9687  Virtua Fighter CG Portrait Series Vol.2: Jacky...      SAT
# 15978       15979      Ciel Nosurge: Ushinawareta Hoshi e Sasagu Uta      PSV
# 10987       10988                                          Fast Food     2600
# 1811         1812                               Pokemon Rumble Blast      3DS
# 12892       12893                        Juiced 2: Hot Import Nights      PS3
# 12433       12434                           MotorStorm: Pacific Rift      PS3
# 11912       11913                                 Virtua Tennis 2009     X360
# 160           161                                         PictoImage       DS
# 15691       15692    Dragon Ball: Origins (JP & incomplete US sales)       DS
# ...

# %%
df_vgm2.describe()
# Out:
#          Unnamed: 0          Year
# count  16598.000000  16327.000000
# mean    8299.500000   1994.242543
# std     4791.574219    155.077168
# min        1.000000      0.000000
# 25%     4150.250000   2003.000000
# 50%     8299.500000   2007.000000
# 75%    12448.750000   2010.000000
# max    16598.000000   2020.000000

# %%
df_vgm2[['Genre', 'Year']]
# Out:
#            Genre    Year
# 0         Action  2008.0
# 1         Action  2009.0
# 2      Adventure  2010.0
# 3           Misc  2010.0
# 4       Platform  2010.0
# ...          ...     ...
# 16593   Platform  2006.0
# 16594     Action  2005.0
# 16595     Sports  2015.0
# 16596     Action  2013.0
# 16597   Fighting  1996.0
#
# [16598 rows x 2 columns]

# %%
df_vgm2.drop('Unnamed: 0', axis = 1, inplace=True)
df_vgm2
# Out:
#                                                  Name Platform    Year  \
# 0                        Candace Kane's Candy Factory       DS  2008.0
# 1                                      The Munchables      Wii  2009.0
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 3                    Deal or No Deal: Special Edition       DS  2010.0
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16593                         Ice Age 2: The Meltdown       GC  2006.0
# 16594                     Rainbow Islands: Revolution      PSP  2005.0
# 16595                                        NBA 2K16      PS3  2015.0
# 16596                     Toukiden: The Age of Demons      PSV  2013.0
# 16597                        The King of Fighters '95       PS  1996.0
#
#            Genre                    Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %%
df_vgm2
# Out:
#                                                  Name Platform    Year  \
# 0                        Candace Kane's Candy Factory       DS  2008.0
# 1                                      The Munchables      Wii  2009.0
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 3                    Deal or No Deal: Special Edition       DS  2010.0
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16593                         Ice Age 2: The Meltdown       GC  2006.0
# 16594                     Rainbow Islands: Revolution      PSP  2005.0
# 16595                                        NBA 2K16      PS3  2015.0
# 16596                     Toukiden: The Age of Demons      PSV  2013.0
# 16597                        The King of Fighters '95       PS  1996.0
#
#            Genre                    Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %%
df1=df_vgm2['Year']

# %%
df_vgm2['NA_Sales'].unique()

# %%
df_vgm2.isnull().sum()
# Out:
# Name             0
# Platform         0
# Year           271
# Genre           50
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# dtype: int64

# %%
df_vgm2['EU_Sales'].unique()
# Out:
# array(['0', '0.09', '0.01', '0.03', '0.33M', '0.05', '0.02', '0.16',
#        '0.45', '0.04', '0.53', '0.23', '0.1', '0.34', '0.22', '0.2',
#        '0.03M', '0.33', '0.08', '0.26', '0.07', '0.11', '0.17', '0.06',
#        '0.14', '0.12', '0.24', '0.13', '0.21', '0.15', '0.3', '2.38',
#        '0.55', '0K', '1.12', '0.43', '50K', '0.63', '0.35', '1.11',
#        '0.41', '0.01M', '0.89', '3.15', '0.18', '0.54', '0.25', '0.29',
#        '0.61', '0.27', '0.86', '0.87', '0.32', '0.44', '2.48', '0.48',
#        '0.47', '0.66', '0.76', '0.27M', '0.15M', '1.94', '0.97', '0.72',
#        '620K', '0.49', '5.36', '0.31', '0.62', '0.4', '0.57', '0.46',
#        '1.97', '1.02', '1.75', '0.28', '2.46', '0.38', '0.5', '0.9',
#        '0.19', '0.39', '0.67', '0.64', '0.37', '0.51', '2.83', '0.59',
#        '0.75', '0.52', '1.34', '760K', '80K', '5.09', '1.09', '2.19',
#        '2.17', '0.91', '2.26', '0.83', '0.74', '0.88', '0.77', '1.24',
# ...

# %%
df_vgm2['JP_Sales'].unique()

# %%
df_vgm2.set_index('Genre')
# Out:
#                                                      Name Platform    Year  \
# Genre
# Action                       Candace Kane's Candy Factory       DS  2008.0
# Action                                     The Munchables      Wii  2009.0
# Adventure  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# Misc                     Deal or No Deal: Special Edition       DS  2010.0
# Platform        Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                                   ...      ...     ...
# Platform                          Ice Age 2: The Meltdown       GC  2006.0
# Action                        Rainbow Islands: Revolution      PSP  2005.0
# Sports                                           NBA 2K16      PS3  2015.0
# Action                        Toukiden: The Age of Demons      PSV  2013.0
# Fighting                         The King of Fighters '95       PS  1996.0
#
# ...

# %%
df_vgm2.sort_values(by='Genre')
# Out:
#                                     Name Platform    Year   Genre  \
# 0           Candace Kane's Candy Factory       DS  2008.0  Action
# 10068   Spider-Man: Shattered Dimensions      PS3  2010.0  Action
# 10062  Star Wars: The Force Unleashed II       DS  2010.0  Action
# 2291                          Just Cause       PC  2006.0  Action
# 10061     Castlevania: Lords of Shadow 2     X360  2014.0  Action
# ...                                  ...      ...     ...     ...
# 15526                         Bloodborne      PS4  2015.0     NaN
# 16091             Brain Boost: Beta Wave       DS  2005.0     NaN
# 16431  Cars: Mater-National Championship     X360  2007.0     NaN
# 16555                Apache: Air Assault       PC  2010.0     NaN
# 16587       Need for Speed Underground 2       XB  2004.0     NaN
#
#                           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 0                         Destineer     0.04        0        0           0
# ...

# %%
df_vgm2.sort_values(by='Genre',ascending=False)
# Out:
#                                     Name Platform    Year     Genre  \
# 11661   Romance of the Three Kingdoms II     SNES  1991.0  Strategy
# 15325    SNK vs. Capcom Card Fighters DS       DS  2006.0  Strategy
# 2825      StarCraft II: Wings of Liberty       PC  2010.0  Strategy
# 635            The Stronghold Collection       PC  2009.0  Strategy
# 9356                  Hearts of Iron III       PC  2009.0  Strategy
# ...                                  ...      ...     ...       ...
# 15526                         Bloodborne      PS4  2015.0       NaN
# 16091             Brain Boost: Beta Wave       DS  2005.0       NaN
# 16431  Cars: Mater-National Championship     X360  2007.0       NaN
# 16555                Apache: Air Assault       PC  2010.0       NaN
# 16587       Need for Speed Underground 2       XB  2004.0       NaN
#
#                          Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 11661                   Tecmo Koei        0        0     0.25           0
# ...

# %%
counts = df_vgm2.Genre.value_counts()
counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2bfd6aac42e1> in <module>
# ----> 1 counts = df_vgm2.Genre.value_counts()
#       2 counts
#
# NameError: name 'df_vgm2' is not defined

# %%
counts.nlargest(3)
# Out:
# Action    3305
# Sports    2341
# Misc      1734
# Name: Genre, dtype: int64

# %%
df_vgm2[df_vgm2.Genre.isin(counts.nlargest(3).index)].head()
# Out:
#                                Name Platform    Year   Genre  \
# 0      Candace Kane's Candy Factory       DS  2008.0  Action
# 1                    The Munchables      Wii  2009.0  Action
# 3  Deal or No Deal: Special Edition       DS  2010.0    Misc
# 5            Power Pro Kun Pocket 8       DS  2005.0  Sports
# 7    Samurai Warriors: State of War      PSP  2005.0  Action
#
#                       Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 0                     Destineer     0.04        0        0           0
# 1            Namco Bandai Games     0.17        0        0        0.01
# 3                     Zoo Games     0.04        0        0           0
# 5  Konami Digital Entertainment        0        0     0.14           0
# 7                    Tecmo Koei     0.07        0     0.11        0.01

# %%
df_vgm2['Genre'].unique()
# Out:
# array(['Action', 'Adventure', 'Misc', 'Platform', 'Sports', 'Simulation',
#        'Racing', 'Role-Playing', 'Puzzle', 'Strategy', 'Fighting',
#        'Shooter', nan], dtype=object)

# %%
df_vgm2['Platform'].unique()
# Out:
# array(['DS', 'Wii', 'PSP', 'PS3', 'PC', 'PS', 'GBA', 'PS4', 'PS2', 'XB',
#        'X360', 'GC', '3DS', '2600', 'SAT', 'GB', 'NES', 'DC', 'N64',
#        'XOne', 'SNES', 'WiiU', 'PSV', 'GEN', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
error1 = df_vgm2[df_vgm2.NA_Sales.str.contains(r'[^0-9]')]
# Out:
#                                                     Name Platform    Year  \
# 4              Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# 6                  JASF: Jane's Advanced Strike Fighters       PC  2011.0
# 9      The Penguins of Madagascar: Dr. Blowhole Retur...      PS3  2011.0
# 10                                           Ford Racing       PS  2001.0
# 11            Harvest Moon: More Friends of Mineral Town      GBA  2003.0
# ...                                                  ...      ...     ...
# 16588                                           MindJack      PS3  2011.0
# 16591                                    Madden NFL 2005      PS2  2004.0
# 16593                            Ice Age 2: The Meltdown       GC  2006.0
# 16595                                           NBA 2K16      PS3  2015.0
# 16596                        Toukiden: The Age of Demons      PSV  2013.0
#
#             Genre             Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_vgm2 = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/datasets/vgames2.csv')
df_vgm2

df1 = df_vgm2[['Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
df1
# Out:
#            Genre NA_Sales EU_Sales JP_Sales Other_Sales
# 0         Action     0.04        0        0           0
# 1         Action     0.17        0        0        0.01
# 2      Adventure        0        0     0.02           0
# 3           Misc     0.04        0        0           0
# 4       Platform     0.12     0.09        0        0.04
# ...          ...      ...      ...      ...         ...
# 16593   Platform     0.15     0.04        0        0.01
# 16594     Action     0.01        0        0           0
# 16595     Sports     0.44     0.19     0.03        0.13
# 16596     Action     0.05     0.05     0.25        0.03
# 16597   Fighting        0        0     0.16        0.01
#
# [16598 rows x 5 columns]

# %%
df2 = df1.set_index(['Genre']).sort_values(by = 'Genre', ascending=False)
df2
# Out:
#          NA_Sales EU_Sales JP_Sales Other_Sales
# Genre
# Strategy        0        0     0.25           0
# Strategy     0.09        0        0        0.01
# Strategy     2.56     1.68        0        0.59
# Strategy     0.03     0.08        0        0.02
# Strategy     0.01     0.04        0        0.01
# ...           ...      ...      ...         ...
# NaN             1     0.76     0.26        0.36
# NaN          0.14        0        0        0.01
# NaN          0.13        0        0        0.01
# NaN             0     0.03        0        0.01
# NaN          1.38      0.8        0         0.1
#
# [16598 rows x 4 columns]

# %%
df_vgm2['NA_Sales'] = df_vgm2['NA_Sales'].str.replace(pat = r'[M, K]', repl = r'', regex = True)
df_vgm2['EU_Sales'] = df_vgm2['EU_Sales'].str.replace(pat = r'[M, K]', repl = r'', regex = True)
df_vgm2['JP_Sales'] = df_vgm2['JP_Sales'].str.replace(pat = r'[M, K]', repl = r'', regex = True)
df_vgm2['Other_Sales'] = df_vgm2['Other_Sales'].str.replace(pat = r'[M, K]', repl = r'', regex = True)

df_vgm2[['NA_Sales', 'EU_Sales','JP_Sales', 'Other_Sales']] =  df_vgm2[['NA_Sales', 'EU_Sales','JP_Sales', 'Other_Sales']].\
apply(pd.to_numeric)

df_vgm2.dtypes
# Out:
# Unnamed: 0       int64
# Name            object
# Platform        object
# Year           float64
# Genre           object
# Publisher       object
# NA_Sales       float64
# EU_Sales       float64
# JP_Sales       float64
# Other_Sales    float64
# dtype: object

# %%
df1 = df_vgm2[['Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
df1
# Out:
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0         Action      0.04      0.00      0.00         0.00
# 1         Action      0.17      0.00      0.00         0.01
# 2      Adventure      0.00      0.00      0.02         0.00
# 3           Misc      0.04      0.00      0.00         0.00
# 4       Platform      0.12      0.09      0.00         0.04
# ...          ...       ...       ...       ...          ...
# 16593   Platform      0.15      0.04      0.00         0.01
# 16594     Action      0.01      0.00      0.00         0.00
# 16595     Sports      0.44      0.19      0.03         0.13
# 16596     Action      0.05      0.05      0.25         0.03
# 16597   Fighting      0.00      0.00      0.16         0.01
#
# [16598 rows x 5 columns]

# %%
df_genre = df_vgm2[['Genre','NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
df_genre.groupby('Genre').describe()
# Out:
#              NA_Sales                                                      \
#                 count      mean        std  min   25%   50%   75%     max
# Genre
# Action         3305.0  2.389646  75.132055  0.0  0.02  0.10  0.27  4100.0
# Adventure      1280.0  0.293273   5.370954  0.0  0.00  0.00  0.07   150.0
# Fighting        847.0  1.218878  19.914883  0.0  0.00  0.08  0.29   470.0
# Misc           1734.0  2.401551  53.169141  0.0  0.00  0.08  0.21  2010.0
# Platform        884.0  4.245622  99.120589  0.0  0.05  0.14  0.44  2930.0
# Puzzle          578.0  0.939325  14.798830  0.0  0.01  0.05  0.14   350.0
# Racing         1243.0  4.699678  83.362442  0.0  0.03  0.10  0.27  2570.0
# Role-Playing   1483.0  1.030566  17.865874  0.0  0.00  0.04  0.16   550.0
# Shooter        1308.0  2.514687  53.687100  0.0  0.03  0.12  0.38  1780.0
# Simulation      865.0  3.526116  58.767918  0.0  0.00  0.07  0.25  1610.0
# Sports         2341.0  1.899509  39.657660  0.0  0.02  0.11  0.30  1610.0
# ...

# %%
df_genre_Action = df_genre.loc[df_genre['Genre'] == 'Action']
df_genre_Action
# Out:
#         Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0      Action      0.04      0.00      0.00         0.00
# 1      Action      0.17      0.00      0.00         0.01
# 7      Action      0.07      0.00      0.11         0.01
# 9      Action      0.04      0.03      0.00         0.01
# 15     Action      0.14      0.16      0.00         0.06
# ...       ...       ...       ...       ...          ...
# 16575  Action      0.36      0.64      0.00         0.08
# 16581  Action      0.13      0.12      0.00         0.02
# 16583  Action      0.91      0.39      0.00         0.13
# 16594  Action      0.01      0.00      0.00         0.00
# 16596  Action      0.05      0.05      0.25         0.03
#
# [3305 rows x 5 columns]

# %%
df_genre_Action['NA_Sales'].sum()
# Out:
# 7897.779999999999

# %%
df_genre_Action['NA_Sales'].unique()
# Out:
# array([4.00e-02, 1.70e-01, 7.00e-02, 1.40e-01, 1.90e-01, 1.10e-01,
#        0.00e+00, 6.00e+01, 1.30e-01, 1.80e-01, 8.00e-02, 3.00e-02,
#        2.20e-01, 1.00e-01, 6.70e-01, 9.00e-02, 4.40e-01, 5.00e-02,
#        2.90e-01, 2.00e-02, 4.70e-01, 6.20e-01, 2.40e-01, 7.20e-01,
#        1.74e+00, 1.60e-01, 6.00e-02, 1.20e-01, 3.20e-01, 3.90e-01,
#        5.70e-01, 2.60e-01, 4.00e-01, 2.30e-01, 5.60e-01, 2.10e-01,
#        3.70e-01, 1.00e-02, 5.80e-01, 8.60e-01, 5.50e-01, 1.02e+00,
#        5.00e-01, 2.80e-01, 5.40e-01, 1.50e-01, 2.29e+00, 3.00e-01,
#        4.10e-01, 2.30e+00, 9.90e-01, 7.00e-01, 4.50e-01, 7.50e-01,
#        6.80e-01, 1.23e+00, 5.10e-01, 4.80e-01, 2.90e+00, 7.80e-01,
#        3.38e+00, 8.20e-01, 4.30e-01, 5.20e-01, 1.08e+00, 3.60e-01,
#        4.20e-01, 3.30e-01, 5.90e-01, 3.83e+00, 3.50e-01, 3.80e-01,
#        3.79e+00, 6.50e-01, 2.00e-01, 3.10e-01, 2.50e-01, 1.05e+00,
#        8.90e-01, 6.30e-01, 1.85e+00, 2.06e+00, 1.36e+00, 6.40e-01,
# ...
