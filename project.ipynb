# %% [markdown]
# <a href="https://colab.research.google.com/github/Choyoons/Choyoons/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_vgm2 = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/datasets/vgames2.csv')
df_vgm2
# Out:
#        Unnamed: 0                                            Name Platform  \
# 0               1                    Candace Kane's Candy Factory       DS
# 1               2                                  The Munchables      Wii
# 2               3  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP
# 3               4                Deal or No Deal: Special Edition       DS
# 4               5       Ben 10 Ultimate Alien: Cosmic Destruction      PS3
# ...           ...                                             ...      ...
# 16593       16594                         Ice Age 2: The Meltdown       GC
# 16594       16595                     Rainbow Islands: Revolution      PSP
# 16595       16596                                        NBA 2K16      PS3
# 16596       16597                     Toukiden: The Age of Demons      PSV
# 16597       16598                        The King of Fighters '95       PS
#
# ...

# %%
df_vgm2.drop('Unnamed: 0', axis = 1, inplace=True)
df_vgm2
# Out:
#                                                  Name Platform    Year  \
# 0                        Candace Kane's Candy Factory       DS  2008.0
# 1                                      The Munchables      Wii  2009.0
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 3                    Deal or No Deal: Special Edition       DS  2010.0
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16593                         Ice Age 2: The Meltdown       GC  2006.0
# 16594                     Rainbow Islands: Revolution      PSP  2005.0
# 16595                                        NBA 2K16      PS3  2015.0
# 16596                     Toukiden: The Age of Demons      PSV  2013.0
# 16597                        The King of Fighters '95       PS  1996.0
#
#            Genre                    Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %%
df1 = df_vgm2[['Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
df1
# Out:
#            Genre NA_Sales EU_Sales JP_Sales Other_Sales
# 0         Action     0.04        0        0           0
# 1         Action     0.17        0        0        0.01
# 2      Adventure        0        0     0.02           0
# 3           Misc     0.04        0        0           0
# 4       Platform     0.12     0.09        0        0.04
# ...          ...      ...      ...      ...         ...
# 16593   Platform     0.15     0.04        0        0.01
# 16594     Action     0.01        0        0           0
# 16595     Sports     0.44     0.19     0.03        0.13
# 16596     Action     0.05     0.05     0.25        0.03
# 16597   Fighting        0        0     0.16        0.01
#
# [16598 rows x 5 columns]

# %%
df_total = df_vgm2[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
df_total
# Out:
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 0         0.04        0        0           0
# 1         0.17        0        0        0.01
# 2            0        0     0.02           0
# 3         0.04        0        0           0
# 4         0.12     0.09        0        0.04
# ...        ...      ...      ...         ...
# 16593     0.15     0.04        0        0.01
# 16594     0.01        0        0           0
# 16595     0.44     0.19     0.03        0.13
# 16596     0.05     0.05     0.25        0.03
# 16597        0        0     0.16        0.01
#
# [16598 rows x 4 columns]

# %%
df_total = df_total.replace('M','', regex = True)
df_total

filter = 
df_total2  = df_total.contains('K')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-c70b66b64c1f> in <module>
#       2 df_total
#       3
# ----> 4 df_total2  = df_total.contains('K')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'contains'

# %%
df1['NA_Sales'] = df1['NA_Sales'].str.replace(pat = r'[M]', repl = r'', regex = True)
df1['EU_Sales'] = df1['EU_Sales'].str.replace(pat = r'[M]', repl = r'', regex = True)
df1['JP_Sales'] = df1['JP_Sales'].str.replace(pat = r'[M]', repl = r'', regex = True)
df1['Other_Sales'] = df1['Other_Sales'].str.replace(pat = r'[M]', repl = r'', regex = True)

df1.dtypes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_vgm2[['NA_Sales', 'EU_Sales','JP_Sales', 'Other_Sales']] =  df_vgm2[['NA_Sales', 'EU_Sales','JP_Sales', 'Other_Sales']].\
apply(pd.to_numeric)

df_vgm2.dtypes

# %%
df_K1 = df1.loc[df1['NA_Sales'].str.contains('K')]
df_K2 = df1.loc[df1['EU_Sales'].str.contains('K')]
df_K3 = df1.loc[df1['JP_Sales'].str.contains('K')]
df_K4 = df1.loc[df1['Other_Sales'].str.contains('K')]

df_K1['NA_Sales']
# Out:
# 10       480K
# 45        60K
# 145        0K
# 878        0K
# 1086       0K
#          ...
# 15647      0K
# 16194    120K
# 16330    720K
# 16492    470K
# 16578    320K
# Name: NA_Sales, Length: 100, dtype: object

# %%
df_K['NA_Sales'] = df_K['NA_Sales'].str.replace(pat = r'[K]', repl = r'', regex = True)
df_K
df_K['NA_Sales'] = df_K['NA_Sales'].astype({'NA_Sales' : 'int'})
df_K.dtypes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Genre          object
# NA_Sales        int64
# EU_Sales       object
# JP_Sales       object
# Other_Sales    object
# dtype: object

# %%
df_K
# Out:
# Empty DataFrame
# Columns: [Genre, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %%
df1['NA_Sales'].str.contains('K')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16593    False
# 16594    False
# 16595    False
# 16596    False
# 16597    False
# Name: NA_Sales, Length: 16598, dtype: bool

# %%
df_vgm2_K['NA_Sales_Num'] = df_vgm2_K['NA_Sales_Num'].str.replace(pat = r'[]', repl = r'', regex = True)
df_vgm2_K
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-d984738ff721> in <module>
# ----> 1 df_vgm2_K['NA_Sales_Num'] = df_vgm2_K['NA_Sales_Num'].str.replace(pat = r'[,]', repl = r'', regex = True)
#       2 df_vgm2_K
#       3
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df1 = df_vgm2[['Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
df1
# Out:
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0         Action      0.04      0.00      0.00         0.00
# 1         Action      0.17      0.00      0.00         0.01
# 2      Adventure      0.00      0.00      0.02         0.00
# 3           Misc      0.04      0.00      0.00         0.00
# 4       Platform      0.12      0.09      0.00         0.04
# ...          ...       ...       ...       ...          ...
# 16593   Platform      0.15      0.04      0.00         0.01
# 16594     Action      0.01      0.00      0.00         0.00
# 16595     Sports      0.44      0.19      0.03         0.13
# 16596     Action      0.05      0.05      0.25         0.03
# 16597   Fighting      0.00      0.00      0.16         0.01
#
# [16598 rows x 5 columns]

# %%
df_genre = df_vgm2[['Genre','NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
df_genre.groupby('Genre').describe()
# Out:
#              NA_Sales                                                      \
#                 count      mean        std  min   25%   50%   75%     max
# Genre
# Action         3305.0  2.389646  75.132055  0.0  0.02  0.10  0.27  4100.0
# Adventure      1280.0  0.293273   5.370954  0.0  0.00  0.00  0.07   150.0
# Fighting        847.0  1.218878  19.914883  0.0  0.00  0.08  0.29   470.0
# Misc           1734.0  2.401551  53.169141  0.0  0.00  0.08  0.21  2010.0
# Platform        884.0  4.245622  99.120589  0.0  0.05  0.14  0.44  2930.0
# Puzzle          578.0  0.939325  14.798830  0.0  0.01  0.05  0.14   350.0
# Racing         1243.0  4.699678  83.362442  0.0  0.03  0.10  0.27  2570.0
# Role-Playing   1483.0  1.030566  17.865874  0.0  0.00  0.04  0.16   550.0
# Shooter        1308.0  2.514687  53.687100  0.0  0.03  0.12  0.38  1780.0
# Simulation      865.0  3.526116  58.767918  0.0  0.00  0.07  0.25  1610.0
# Sports         2341.0  1.899509  39.657660  0.0  0.02  0.11  0.30  1610.0
# ...

# %%
#sales가 0인 것은 빼고 각 지역별 Action의 출고량을 나타내고 그 갯수 파악

df_genre_Action_NA = df_genre.loc[(df_genre['Genre'] == 'Action') & df_genre['NA_Sales'] > 0]
df_genre_Action_NA
df_genre_Action_NA['NA_Sales'].count()
# Out:
# 2573

# %%
df_genre_Action_NA['NA_Sales'].sum()
# Out:
# 7897.779999999999

# %%
df1['NA_Sales']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_vgm2 = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/datasets/vgames2.csv')
df_vgm2

df_vgm2[df_vgm2['NA_Sales'].isnull()| df_vgm2['EU_Sales'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %%
df_vgm2.NA_Sales.sort_values()
# Out:
# 8298        0
# 7847        0
# 7846        0
# 7845        0
# 7843        0
#          ...
# 6248     9.67
# 10650    9.81
# 14347     90K
# 13798     90K
# 13057     90K
# Name: NA_Sales, Length: 16598, dtype: object

# %%
sum_sales=[]
for i in range(df_vgm2.shape[0]):
  sum_sales.append(df_vgm2.iloc[i,5:].sum())
df_vgm2['Sum_Sales'] = sum_sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dbc6d44725ff> in <module>
#       1 sum_sales=[]
# ----> 2 for i in range(df_vgm2.shape[0]):
#       3   sum_sales.append(df_vgm2.iloc[i,5:].sum())
#       4 df_vgm2['Sum_Sales'] = sum_sales
#
# NameError: name 'df_vgm2' is not defined

# %%
df_vgm2[df_vgm2['Genre'].isnull()]
# Out:
#        Unnamed: 0                                         Name Platform  \
# 50             51                     Ape Escape: On the Loose      PSP
# 408           409                                  NBA Ballers       XB
# 1328         1329                                   NFL Street       XB
# 1582         1583               SingStar Singalong With Disney      PS2
# 1971         1972                          Pokemon X/Pokemon Y      3DS
# 2043         2044                                NASCAR Racing       PS
# 2497         2498             Jurassic Park III: Island Attack      GBA
# 3353         3354                  The Godfather: Dons Edition      PS3
# 3363         3364                 Ski-Doo Snowmobile Challenge     X360
# 3470         3471           Batman Beyond: Return of the Joker      N64
# 3515         3516     Princess Saver! Eternal Love for My Lady      PS2
# 3932         3933                            MVP Baseball 2004      PS2
# ...
